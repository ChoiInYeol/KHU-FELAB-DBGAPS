# %%
def get_environment():
    try:
        # Check if the environment is Google Colab
        import google.colab
        return "colab"
    except ImportError:
        # Environment is not Google Colab, assume it is local
        return "local"

environment = get_environment()

if environment == "colab":
    colab_path = "/content/drive/MyDrive/Colab Notebooks/"
    from google.colab import drive
    drive.mount('/content/drive')
    # !pip install finance-datareader
elif environment == "local":
    colab_path = ""

# %% [markdown]
# 함수 import

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from scipy import stats
from scipy.optimize import minimize

from datetime import timedelta

# Neural Network library
import tensorflow as tf
import tensorflow_probability as tfp

from tensorflow import keras
from tensorflow.python.keras.models import load_model
from keras import callbacks
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.layers import Activation
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.regularizers import l2

import matplotlib.pyplot as plt
plt.style.use("bmh")

# 한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager, rc
plt.rc('font', family='Pretendard') # For Windows
# %matplotlib inline

# %% [markdown]
# MV 모델 벤치마크

# %%
def calc_portfolio_std(weights, mean_returns, cov):
    portfolio_std = np.sqrt(np.dot(weights.T, np.dot(cov, weights)))
    return portfolio_std

def calc_neg_sharpe(weights, mean_returns, cov, rf):
    portfolio_return = np.sum(mean_returns * weights)
    portfolio_std = np.sqrt(np.dot(weights.T, np.dot(cov, weights)))
    sharpe_ratio = (portfolio_return - rf) / portfolio_std
    return -sharpe_ratio

def calc_portfolio_VaR(weights, mean_returns, cov, alpha):
    portfolio_return = np.sum(mean_returns * weights)
    portfolio_std = np.sqrt(np.dot(weights.T, np.dot(cov, weights)))
    portfolio_var = abs(portfolio_return - (portfolio_std * stats.norm.ppf(1 - alpha)))
    return portfolio_return, portfolio_std, portfolio_var

def portfolio_optimization_std(w, r, cov):
    constraints = [{'type': 'eq', 'fun': lambda x: np.sum(x) - 1}]
    args = (r, cov)
    bound = (0.0, 1.0)
    bounds = tuple(bound for asset in range(len(w)))
    optimization_result = minimize(calc_portfolio_std, w, args=args, method='SLSQP', bounds=bounds, constraints=constraints)
    
    return optimization_result

def portfolio_optimization_sharpe(w, r, cov, rf):
    constraints = [{'type': 'eq', 'fun': lambda x: np.sum(x) - 1}]
    args = (r, cov, rf)
    bound = (0.0, 1.0)
    bounds = tuple(bound for asset in range(len(w)))
    optimization_result = minimize(calc_neg_sharpe, w, args=args, method='SLSQP', bounds=bounds, constraints=constraints)
    
    return optimization_result

def portfolio_optimization_Var(w, r, cov, alpha):
    constraints = [{'type': 'eq', 'fun': lambda x: np.sum(x) - 1}]
    args = (r, cov, alpha)
    bound = (0.0, 1.0)
    bounds = tuple(bound for asset in range(len(w)))
    optimization_result = minimize(calc_portfolio_VaR, w, args=args, method='SLSQP', bounds=bounds, constraints=constraints)
    
    return optimization_result

# %% [markdown]
# ## 2002-01-01 부터 학습하여 2018년 이후의 백테스트

# %%
df = pd.read_csv(colab_path + "0526_data.csv", index_col="Date")
df
# Out:
#               CSI300    KOSDAQ     KOSPI  KOSPI-Short       MMF  Nikkei225
# Date
# 2015-10-14  0.032716 -0.012458 -0.004400    -0.000609  0.000196  -0.013886  \
# 2015-10-15  0.023419  0.008163  0.011972    -0.013489  0.000196   0.011443
# 2015-10-16  0.013460  0.014717 -0.002100     0.001850  0.000000   0.010712
# 2015-10-19  0.000031 -0.000943  0.000404     0.001847  0.000049  -0.008817
# 2015-10-21 -0.017391  0.005644  0.007167    -0.007407 -0.000196   0.023065
# ...              ...       ...       ...          ...       ...        ...
# 2023-05-19 -0.003955  0.000791  0.023063    -0.022716  0.000097   0.023474
# 2023-05-22  0.006265  0.018019  0.006085    -0.007688  0.000000   0.008998
# 2023-05-23 -0.014244  0.011195  0.002436    -0.001103  0.000097  -0.004160
# 2023-05-25 -0.016150 -0.019380 -0.005175     0.004405  0.000195  -0.005073
# 2023-05-26  0.000117 -0.003136  0.005234    -0.003302  0.000000   0.003732
#
#               S&P500   STOXX50   US-Long  US-Short       WTI     국채10년
# Date
# 2015-10-14 -0.009577 -0.010408 -0.009589  0.009246 -0.058099 -0.002759  \
# 2015-10-15  0.014744  0.014693 -0.013072  0.013711 -0.005590  0.005052
# 2015-10-16  0.004560  0.008032 -0.001699  0.001814  0.018796 -0.000542
# 2015-10-19  0.000271  0.002175 -0.007682  0.009021 -0.029417 -0.000750
# 2015-10-21 -0.007265  0.000058  0.008957 -0.010835 -0.015150 -0.003592
# ...              ...       ...       ...       ...       ...       ...
# 2023-05-19  0.007954  0.016533 -0.006254  0.007301 -0.017731 -0.007095
# 2023-05-22  0.000155 -0.002202 -0.005943  0.006137  0.006131  0.002058
# 2023-05-23 -0.011285 -0.009911 -0.004921  0.005546  0.012699 -0.005916
# 2023-05-25  0.001374 -0.016893  0.011212 -0.011683 -0.014924 -0.009349
# 2023-05-26  0.012965  0.015769 -0.001046  0.001677  0.011626 -0.002180
#
#                    금     우량회사채      해외채권
# Date
# 2015-10-14  0.030457 -0.000144 -0.004830
# 2015-10-15  0.006588  0.000914  0.002359
# 2015-10-16 -0.003626 -0.000577  0.004584
# 2015-10-19 -0.008740  0.000240  0.002694
# 2015-10-21 -0.004870  0.000000 -0.000118
# ...              ...       ...       ...
# 2023-05-19 -0.001010 -0.001244  0.001618
# 2023-05-22 -0.001973  0.000191  0.004438
# 2023-05-23 -0.001216 -0.000096 -0.005247
# 2023-05-25 -0.014966 -0.001629 -0.007718
# 2023-05-26  0.000515 -0.000863  0.006098
#
# [1598 rows x 15 columns]

# %%
df = pd.read_csv(colab_path + "0526_data.csv", index_col="Date")
train, test = train_test_split(df, test_size=0.2, shuffle=False)

train_len = len(train)
test_len = len(test)
validation_set_len = 65
validation_set_split_point = 60
future_set_len = 5
N_STOCKS = 15

xc_train = np.empty((train_len - validation_set_len, validation_set_split_point, N_STOCKS))
xf_train = np.empty((train_len - validation_set_len, future_set_len, N_STOCKS))
xc_test = np.empty((test_len - validation_set_len, validation_set_split_point, N_STOCKS))
xf_test = np.empty((test_len - validation_set_len, future_set_len, N_STOCKS))

for idx in range(train_len - validation_set_len):
    temp_xc_train = train[idx : idx + validation_set_split_point]
    temp_xf_train = train[idx + validation_set_split_point : idx + validation_set_len]

    xc_train[idx] = temp_xc_train
    xf_train[idx] = temp_xf_train

for idx in range(test_len - validation_set_len):
    temp_xc_test = test[idx : idx + validation_set_split_point]
    temp_xf_test = test[idx + validation_set_split_point : idx + validation_set_len]

    xc_test[idx] = temp_xc_test
    xf_test[idx] = temp_xf_test
    
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') * 5
xf_train = xf_train.astype('float32') * 5
xc_test = xc_test.astype('float32') * 5
xf_test = xf_test.astype('float32') * 5

N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
xc_train, xf_train = shuffle(xc_train, xf_train)

# %%
# over confidence를 제어할 조절 변수 정의
GAMMA_CONST = 0.1
REG_CONST = 0.0

# 최적 포트폴리오를 구축할 목표 함수를 정의한다.
# MPN에서는 이 함수를 loss로 이용한다. max(objective) = min(-objective)
# y_true = model.fit()에서 전달된 N_FUTURE일 후의 수익률 (xf_train)이 들어온다.
# y_pred = 마코비츠 네트워크의 출력이 전달된다. (keras 내부 기능)

def markowitz_objective(y_true, y_pred):
    W = y_pred      # 마코비츠 네트워크의 출력
    xf_rtn = y_true
    W = tf.expand_dims(W, axis = 1)
    R = tf.expand_dims(tf.reduce_mean(xf_rtn, axis = 1), axis = 2)
    C = tfp.stats.covariance(xf_rtn, sample_axis=1)

    rtn = tf.matmul(W, R)  
    vol = tf.matmul(W, tf.matmul(C, tf.transpose(W, perm = [0, 2, 1]))) * GAMMA_CONST
    reg = tf.reduce_sum(tf.square(W), axis = -1) * REG_CONST
    objective = rtn - vol - reg
    
    return -tf.reduce_mean(objective, axis=0)

# LSTM으로 Markowitz 모델을 생성한다.
xc_input = tf.keras.Input(batch_shape = (None, N_TIME, N_STOCKS))
h_lstm = LSTM(64, dropout = 0.5, kernel_regularizer=l2(0.005))(xc_input)
y_output = Dense(N_STOCKS, activation='relu')(h_lstm)  # linear projection

# 마코비츠의 최적 weights
y_output = Activation('softmax')(y_output)
model = tf.keras.Model(xc_input, y_output)

# %% [markdown]
# prophet이 계속 학습하면 계속 Loss가 줄어듦으로 에포크를 500으로 통일 제한한다.

# %%
# MPN을 학습하고 결과를 저장한다.
SAVE_MODEL = 'Markowitz_network_final'
ealry_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.compile(loss = markowitz_objective, optimizer = Adam(learning_rate = 1e-5))
hist = model.fit(xc_train, xf_train, epochs=500, batch_size = 32, validation_data = (xc_test, xf_test), callbacks=[ealry_stopping], verbose=False)
model.save(SAVE_MODEL + '.h5')
# Out:
# Epoch 1/500
# 38/38 [==============================] - 4s 42ms/step - loss: 0.1402 - val_loss: 0.1414
# Epoch 2/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.1392 - val_loss: 0.1403
# Epoch 3/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.1381 - val_loss: 0.1393
# Epoch 4/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1370 - val_loss: 0.1382
# Epoch 5/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1360 - val_loss: 0.1372
# Epoch 6/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1349 - val_loss: 0.1361
# Epoch 7/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1339 - val_loss: 0.1351
# Epoch 8/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.1328 - val_loss: 0.1341
# Epoch 9/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.1318 - val_loss: 0.1330
# Epoch 10/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1308 - val_loss: 0.1320
# Epoch 11/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1298 - val_loss: 0.1310
# Epoch 12/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1288 - val_loss: 0.1300
# Epoch 13/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1278 - val_loss: 0.1290
# Epoch 14/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1268 - val_loss: 0.1280
# Epoch 15/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.1258 - val_loss: 0.1271
# Epoch 16/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1248 - val_loss: 0.1261
# Epoch 17/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1238 - val_loss: 0.1251
# Epoch 18/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1229 - val_loss: 0.1242
# Epoch 19/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.1219 - val_loss: 0.1232
# Epoch 20/500
# 38/38 [==============================] - 1s 26ms/step - loss: 0.1210 - val_loss: 0.1223
# Epoch 21/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.1200 - val_loss: 0.1213
# Epoch 22/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.1191 - val_loss: 0.1204
# Epoch 23/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.1182 - val_loss: 0.1195
# Epoch 24/500
# 38/38 [==============================] - 1s 29ms/step - loss: 0.1172 - val_loss: 0.1186
# Epoch 25/500
# 38/38 [==============================] - 1s 26ms/step - loss: 0.1163 - val_loss: 0.1176
# Epoch 26/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1154 - val_loss: 0.1167
# Epoch 27/500
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1145 - val_loss: 0.1158
# Epoch 28/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.1136 - val_loss: 0.1149
# Epoch 29/500
# 38/38 [==============================] - 1s 20ms/step - loss: 0.1127 - val_loss: 0.1140
# Epoch 30/500
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1118 - val_loss: 0.1132
# Epoch 31/500
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1109 - val_loss: 0.1123
# Epoch 32/500
# 38/38 [==============================] - 1s 22ms/step - loss: 0.1100 - val_loss: 0.1114
# Epoch 33/500
# 38/38 [==============================] - 1s 22ms/step - loss: 0.1092 - val_loss: 0.1105
# Epoch 34/500
# 38/38 [==============================] - 1s 21ms/step - loss: 0.1083 - val_loss: 0.1097
# Epoch 35/500
# 38/38 [==============================] - 1s 20ms/step - loss: 0.1074 - val_loss: 0.1088
# Epoch 36/500
# 38/38 [==============================] - 1s 19ms/step - loss: 0.1066 - val_loss: 0.1080
# Epoch 37/500
# 38/38 [==============================] - 1s 19ms/step - loss: 0.1057 - val_loss: 0.1071
# Epoch 38/500
# 38/38 [==============================] - 1s 19ms/step - loss: 0.1049 - val_loss: 0.1063
# Epoch 39/500
# 38/38 [==============================] - 1s 19ms/step - loss: 0.1041 - val_loss: 0.1055
# Epoch 40/500
# 38/38 [==============================] - 1s 20ms/step - loss: 0.1032 - val_loss: 0.1046
# Epoch 41/500
# 38/38 [==============================] - 1s 18ms/step - loss: 0.1024 - val_loss: 0.1038
# Epoch 42/500
# 38/38 [==============================] - 1s 19ms/step - loss: 0.1016 - val_loss: 0.1030
# Epoch 43/500
# 38/38 [==============================] - 1s 18ms/step - loss: 0.1008 - val_loss: 0.1022
# Epoch 44/500
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0999 - val_loss: 0.1014
# Epoch 45/500
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0991 - val_loss: 0.1006
# Epoch 46/500
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0983 - val_loss: 0.0998
# Epoch 47/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0975 - val_loss: 0.0990
# Epoch 48/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0967 - val_loss: 0.0982
# Epoch 49/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0959 - val_loss: 0.0974
# Epoch 50/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0952 - val_loss: 0.0967
# Epoch 51/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0944 - val_loss: 0.0959
# Epoch 52/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0936 - val_loss: 0.0951
# Epoch 53/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0929 - val_loss: 0.0944
# Epoch 54/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0921 - val_loss: 0.0936
# Epoch 55/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0913 - val_loss: 0.0929
# Epoch 56/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0906 - val_loss: 0.0921
# Epoch 57/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0898 - val_loss: 0.0914
# Epoch 58/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0891 - val_loss: 0.0907
# Epoch 59/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0883 - val_loss: 0.0899
# Epoch 60/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0876 - val_loss: 0.0892
# Epoch 61/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0868 - val_loss: 0.0885
# Epoch 62/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0861 - val_loss: 0.0878
# Epoch 63/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0854 - val_loss: 0.0871
# Epoch 64/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0846 - val_loss: 0.0864
# Epoch 65/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0839 - val_loss: 0.0858
# Epoch 66/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0832 - val_loss: 0.0851
# Epoch 67/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0824 - val_loss: 0.0845
# Epoch 68/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0817 - val_loss: 0.0839
# Epoch 69/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0809 - val_loss: 0.0835
# Epoch 70/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0800 - val_loss: 0.0830
# Epoch 71/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0791 - val_loss: 0.0828
# Epoch 72/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0782 - val_loss: 0.0825
# Epoch 73/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0774 - val_loss: 0.0822
# Epoch 74/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0766 - val_loss: 0.0817
# Epoch 75/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0758 - val_loss: 0.0812
# Epoch 76/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0751 - val_loss: 0.0808
# Epoch 77/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0744 - val_loss: 0.0802
# Epoch 78/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0737 - val_loss: 0.0797
# Epoch 79/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0730 - val_loss: 0.0792
# Epoch 80/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0723 - val_loss: 0.0786
# Epoch 81/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0716 - val_loss: 0.0781
# Epoch 82/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0710 - val_loss: 0.0775
# Epoch 83/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0703 - val_loss: 0.0770
# Epoch 84/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0697 - val_loss: 0.0765
# Epoch 85/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0690 - val_loss: 0.0759
# Epoch 86/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0684 - val_loss: 0.0754
# Epoch 87/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0677 - val_loss: 0.0748
# Epoch 88/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0671 - val_loss: 0.0743
# Epoch 89/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0664 - val_loss: 0.0737
# Epoch 90/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0658 - val_loss: 0.0732
# Epoch 91/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0652 - val_loss: 0.0726
# Epoch 92/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0646 - val_loss: 0.0721
# Epoch 93/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0640 - val_loss: 0.0716
# Epoch 94/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0634 - val_loss: 0.0710
# Epoch 95/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0628 - val_loss: 0.0705
# Epoch 96/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0622 - val_loss: 0.0699
# Epoch 97/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0616 - val_loss: 0.0694
# Epoch 98/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0610 - val_loss: 0.0689
# Epoch 99/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0604 - val_loss: 0.0684
# Epoch 100/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0598 - val_loss: 0.0679
# Epoch 101/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0592 - val_loss: 0.0674
# Epoch 102/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0587 - val_loss: 0.0668
# Epoch 103/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0581 - val_loss: 0.0663
# Epoch 104/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0575 - val_loss: 0.0658
# Epoch 105/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0570 - val_loss: 0.0653
# Epoch 106/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0564 - val_loss: 0.0648
# Epoch 107/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0559 - val_loss: 0.0643
# Epoch 108/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0553 - val_loss: 0.0638
# Epoch 109/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0548 - val_loss: 0.0633
# Epoch 110/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0542 - val_loss: 0.0628
# Epoch 111/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0537 - val_loss: 0.0623
# Epoch 112/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0532 - val_loss: 0.0618
# Epoch 113/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0526 - val_loss: 0.0613
# Epoch 114/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0521 - val_loss: 0.0608
# Epoch 115/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0516 - val_loss: 0.0603
# Epoch 116/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0511 - val_loss: 0.0598
# Epoch 117/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0506 - val_loss: 0.0593
# Epoch 118/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0500 - val_loss: 0.0589
# Epoch 119/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0495 - val_loss: 0.0584
# Epoch 120/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0490 - val_loss: 0.0579
# Epoch 121/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0485 - val_loss: 0.0575
# Epoch 122/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0480 - val_loss: 0.0570
# Epoch 123/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0475 - val_loss: 0.0565
# Epoch 124/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0470 - val_loss: 0.0561
# Epoch 125/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0465 - val_loss: 0.0556
# Epoch 126/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0461 - val_loss: 0.0552
# Epoch 127/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0456 - val_loss: 0.0547
# Epoch 128/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0451 - val_loss: 0.0542
# Epoch 129/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0446 - val_loss: 0.0538
# Epoch 130/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0442 - val_loss: 0.0534
# Epoch 131/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0437 - val_loss: 0.0529
# Epoch 132/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0432 - val_loss: 0.0525
# Epoch 133/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0428 - val_loss: 0.0520
# Epoch 134/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0423 - val_loss: 0.0516
# Epoch 135/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0418 - val_loss: 0.0512
# Epoch 136/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0414 - val_loss: 0.0508
# Epoch 137/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0409 - val_loss: 0.0503
# Epoch 138/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0405 - val_loss: 0.0499
# Epoch 139/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0401 - val_loss: 0.0495
# Epoch 140/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0396 - val_loss: 0.0491
# Epoch 141/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0392 - val_loss: 0.0486
# Epoch 142/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0387 - val_loss: 0.0482
# Epoch 143/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0383 - val_loss: 0.0478
# Epoch 144/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0379 - val_loss: 0.0474
# Epoch 145/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0375 - val_loss: 0.0470
# Epoch 146/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0370 - val_loss: 0.0466
# Epoch 147/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0366 - val_loss: 0.0462
# Epoch 148/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0362 - val_loss: 0.0458
# Epoch 149/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0358 - val_loss: 0.0454
# Epoch 150/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0354 - val_loss: 0.0450
# Epoch 151/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0350 - val_loss: 0.0446
# Epoch 152/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0346 - val_loss: 0.0443
# Epoch 153/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0342 - val_loss: 0.0439
# Epoch 154/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0338 - val_loss: 0.0435
# Epoch 155/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0334 - val_loss: 0.0431
# Epoch 156/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0330 - val_loss: 0.0427
# Epoch 157/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0326 - val_loss: 0.0424
# Epoch 158/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0322 - val_loss: 0.0420
# Epoch 159/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0318 - val_loss: 0.0416
# Epoch 160/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0314 - val_loss: 0.0412
# Epoch 161/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0311 - val_loss: 0.0409
# Epoch 162/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0307 - val_loss: 0.0405
# Epoch 163/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0303 - val_loss: 0.0401
# Epoch 164/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0300 - val_loss: 0.0398
# Epoch 165/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0296 - val_loss: 0.0394
# Epoch 166/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0292 - val_loss: 0.0391
# Epoch 167/500
# 38/38 [==============================] - 1s 26ms/step - loss: 0.0289 - val_loss: 0.0388
# Epoch 168/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0285 - val_loss: 0.0384
# Epoch 169/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0282 - val_loss: 0.0381
# Epoch 170/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0278 - val_loss: 0.0377
# Epoch 171/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0275 - val_loss: 0.0374
# Epoch 172/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0271 - val_loss: 0.0370
# Epoch 173/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0268 - val_loss: 0.0367
# Epoch 174/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0264 - val_loss: 0.0364
# Epoch 175/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0261 - val_loss: 0.0361
# Epoch 176/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0257 - val_loss: 0.0357
# Epoch 177/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0254 - val_loss: 0.0354
# Epoch 178/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0251 - val_loss: 0.0351
# Epoch 179/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0247 - val_loss: 0.0348
# Epoch 180/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0244 - val_loss: 0.0345
# Epoch 181/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0241 - val_loss: 0.0341
# Epoch 182/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0238 - val_loss: 0.0338
# Epoch 183/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0235 - val_loss: 0.0335
# Epoch 184/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0231 - val_loss: 0.0332
# Epoch 185/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0228 - val_loss: 0.0329
# Epoch 186/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0225 - val_loss: 0.0326
# Epoch 187/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0222 - val_loss: 0.0323
# Epoch 188/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0219 - val_loss: 0.0320
# Epoch 189/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0216 - val_loss: 0.0317
# Epoch 190/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0213 - val_loss: 0.0314
# Epoch 191/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0210 - val_loss: 0.0311
# Epoch 192/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0207 - val_loss: 0.0308
# Epoch 193/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0204 - val_loss: 0.0305
# Epoch 194/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0201 - val_loss: 0.0303
# Epoch 195/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0198 - val_loss: 0.0300
# Epoch 196/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0195 - val_loss: 0.0297
# Epoch 197/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0193 - val_loss: 0.0294
# Epoch 198/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0190 - val_loss: 0.0291
# Epoch 199/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0187 - val_loss: 0.0288
# Epoch 200/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0184 - val_loss: 0.0286
# Epoch 201/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0181 - val_loss: 0.0283
# Epoch 202/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0179 - val_loss: 0.0281
# Epoch 203/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0176 - val_loss: 0.0278
# Epoch 204/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0173 - val_loss: 0.0275
# Epoch 205/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0171 - val_loss: 0.0273
# Epoch 206/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0168 - val_loss: 0.0270
# Epoch 207/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0165 - val_loss: 0.0267
# Epoch 208/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0163 - val_loss: 0.0265
# Epoch 209/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0160 - val_loss: 0.0262
# Epoch 210/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0158 - val_loss: 0.0260
# Epoch 211/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0155 - val_loss: 0.0257
# Epoch 212/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0153 - val_loss: 0.0255
# Epoch 213/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0150 - val_loss: 0.0252
# Epoch 214/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0148 - val_loss: 0.0250
# Epoch 215/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0145 - val_loss: 0.0248
# Epoch 216/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0143 - val_loss: 0.0245
# Epoch 217/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0141 - val_loss: 0.0243
# Epoch 218/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0138 - val_loss: 0.0240
# Epoch 219/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0136 - val_loss: 0.0238
# Epoch 220/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0134 - val_loss: 0.0236
# Epoch 221/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0131 - val_loss: 0.0233
# Epoch 222/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0129 - val_loss: 0.0231
# Epoch 223/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0127 - val_loss: 0.0229
# Epoch 224/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0125 - val_loss: 0.0227
# Epoch 225/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0122 - val_loss: 0.0225
# Epoch 226/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0120 - val_loss: 0.0223
# Epoch 227/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0118 - val_loss: 0.0220
# Epoch 228/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0116 - val_loss: 0.0218
# Epoch 229/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0114 - val_loss: 0.0216
# Epoch 230/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0112 - val_loss: 0.0214
# Epoch 231/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0110 - val_loss: 0.0212
# Epoch 232/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0107 - val_loss: 0.0210
# Epoch 233/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0105 - val_loss: 0.0208
# Epoch 234/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0103 - val_loss: 0.0205
# Epoch 235/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0101 - val_loss: 0.0204
# Epoch 236/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0099 - val_loss: 0.0202
# Epoch 237/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0097 - val_loss: 0.0200
# Epoch 238/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0095 - val_loss: 0.0198
# Epoch 239/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0093 - val_loss: 0.0196
# Epoch 240/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0092 - val_loss: 0.0194
# Epoch 241/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0090 - val_loss: 0.0192
# Epoch 242/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0088 - val_loss: 0.0190
# Epoch 243/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0086 - val_loss: 0.0188
# Epoch 244/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0084 - val_loss: 0.0187
# Epoch 245/500
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0082 - val_loss: 0.0185
# Epoch 246/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0080 - val_loss: 0.0183
# Epoch 247/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0079 - val_loss: 0.0181
# Epoch 248/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0077 - val_loss: 0.0180
# Epoch 249/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0075 - val_loss: 0.0178
# Epoch 250/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0073 - val_loss: 0.0176
# Epoch 251/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0072 - val_loss: 0.0174
# Epoch 252/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0070 - val_loss: 0.0173
# Epoch 253/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0068 - val_loss: 0.0171
# Epoch 254/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0067 - val_loss: 0.0170
# Epoch 255/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0065 - val_loss: 0.0168
# Epoch 256/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0064 - val_loss: 0.0166
# Epoch 257/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0062 - val_loss: 0.0165
# Epoch 258/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0060 - val_loss: 0.0163
# Epoch 259/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0059 - val_loss: 0.0161
# Epoch 260/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0057 - val_loss: 0.0160
# Epoch 261/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0056 - val_loss: 0.0159
# Epoch 262/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0054 - val_loss: 0.0157
# Epoch 263/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0053 - val_loss: 0.0155
# Epoch 264/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0051 - val_loss: 0.0154
# Epoch 265/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0050 - val_loss: 0.0152
# Epoch 266/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0048 - val_loss: 0.0151
# Epoch 267/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0047 - val_loss: 0.0149
# Epoch 268/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0045 - val_loss: 0.0148
# Epoch 269/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0044 - val_loss: 0.0147
# Epoch 270/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0043 - val_loss: 0.0145
# Epoch 271/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0041 - val_loss: 0.0144
# Epoch 272/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0040 - val_loss: 0.0143
# Epoch 273/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0039 - val_loss: 0.0141
# Epoch 274/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0037 - val_loss: 0.0140
# Epoch 275/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0036 - val_loss: 0.0139
# Epoch 276/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0035 - val_loss: 0.0137
# Epoch 277/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0033 - val_loss: 0.0136
# Epoch 278/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0032 - val_loss: 0.0135
# Epoch 279/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0031 - val_loss: 0.0133
# Epoch 280/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0030 - val_loss: 0.0132
# Epoch 281/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0029 - val_loss: 0.0131
# Epoch 282/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0027 - val_loss: 0.0130
# Epoch 283/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0026 - val_loss: 0.0129
# Epoch 284/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0025 - val_loss: 0.0127
# Epoch 285/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0024 - val_loss: 0.0126
# Epoch 286/500
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0023 - val_loss: 0.0125
# Epoch 287/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0022 - val_loss: 0.0124
# Epoch 288/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0021 - val_loss: 0.0123
# Epoch 289/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0019 - val_loss: 0.0122
# Epoch 290/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0018 - val_loss: 0.0121
# Epoch 291/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0017 - val_loss: 0.0120
# Epoch 292/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0016 - val_loss: 0.0119
# Epoch 293/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0015 - val_loss: 0.0118
# Epoch 294/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0014 - val_loss: 0.0116
# Epoch 295/500
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0013 - val_loss: 0.0115
# Epoch 296/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0012 - val_loss: 0.0114
# Epoch 297/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0011 - val_loss: 0.0114
# Epoch 298/500
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0010 - val_loss: 0.0113
# Epoch 299/500
# 38/38 [==============================] - 1s 24ms/step - loss: 9.2807e-04 - val_loss: 0.0111
# Epoch 300/500
# 38/38 [==============================] - 1s 24ms/step - loss: 8.3712e-04 - val_loss: 0.0111
# Epoch 301/500
# 38/38 [==============================] - 1s 24ms/step - loss: 7.4040e-04 - val_loss: 0.0110
# Epoch 302/500
# 38/38 [==============================] - 1s 24ms/step - loss: 6.4693e-04 - val_loss: 0.0109
# Epoch 303/500
# 38/38 [==============================] - 1s 24ms/step - loss: 5.5780e-04 - val_loss: 0.0108
# Epoch 304/500
# 38/38 [==============================] - 1s 24ms/step - loss: 4.7381e-04 - val_loss: 0.0107
# Epoch 305/500
# 38/38 [==============================] - 1s 24ms/step - loss: 3.8217e-04 - val_loss: 0.0106
# Epoch 306/500
# 38/38 [==============================] - 1s 24ms/step - loss: 2.9632e-04 - val_loss: 0.0105
# Epoch 307/500
# 38/38 [==============================] - 1s 23ms/step - loss: 2.1105e-04 - val_loss: 0.0104
# Epoch 308/500
# 38/38 [==============================] - 1s 24ms/step - loss: 1.2606e-04 - val_loss: 0.0103
# Epoch 309/500
# 38/38 [==============================] - 1s 24ms/step - loss: 4.2239e-05 - val_loss: 0.0102
# Epoch 310/500
# 38/38 [==============================] - 1s 24ms/step - loss: -3.8234e-05 - val_loss: 0.0102
# Epoch 311/500
# 38/38 [==============================] - 1s 24ms/step - loss: -1.1617e-04 - val_loss: 0.0101
# Epoch 312/500
# 38/38 [==============================] - 1s 25ms/step - loss: -1.9553e-04 - val_loss: 0.0100
# Epoch 313/500
# 38/38 [==============================] - 1s 24ms/step - loss: -2.7530e-04 - val_loss: 0.0099
# Epoch 314/500
# 38/38 [==============================] - 1s 24ms/step - loss: -3.5405e-04 - val_loss: 0.0098
# Epoch 315/500
# 38/38 [==============================] - 1s 24ms/step - loss: -4.2859e-04 - val_loss: 0.0098
# Epoch 316/500
# 38/38 [==============================] - 1s 23ms/step - loss: -5.0126e-04 - val_loss: 0.0097
# Epoch 317/500
# 38/38 [==============================] - 1s 23ms/step - loss: -5.7844e-04 - val_loss: 0.0096
# Epoch 318/500
# 38/38 [==============================] - 1s 23ms/step - loss: -6.4823e-04 - val_loss: 0.0095
# Epoch 319/500
# 38/38 [==============================] - 1s 24ms/step - loss: -7.2194e-04 - val_loss: 0.0095
# Epoch 320/500
# 38/38 [==============================] - 1s 24ms/step - loss: -7.9032e-04 - val_loss: 0.0094
# Epoch 321/500
# 38/38 [==============================] - 1s 24ms/step - loss: -8.5958e-04 - val_loss: 0.0093
# Epoch 322/500
# 38/38 [==============================] - 1s 24ms/step - loss: -9.2709e-04 - val_loss: 0.0092
# Epoch 323/500
# 38/38 [==============================] - 1s 23ms/step - loss: -9.9535e-04 - val_loss: 0.0092
# Epoch 324/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0011 - val_loss: 0.0091
# Epoch 325/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0011 - val_loss: 0.0090
# Epoch 326/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0012 - val_loss: 0.0090
# Epoch 327/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0013 - val_loss: 0.0089
# Epoch 328/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0013 - val_loss: 0.0088
# Epoch 329/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0014 - val_loss: 0.0088
# Epoch 330/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0014 - val_loss: 0.0087
# Epoch 331/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0015 - val_loss: 0.0086
# Epoch 332/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0016 - val_loss: 0.0086
# Epoch 333/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0016 - val_loss: 0.0085
# Epoch 334/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0017 - val_loss: 0.0085
# Epoch 335/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0017 - val_loss: 0.0084
# Epoch 336/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0018 - val_loss: 0.0083
# Epoch 337/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0018 - val_loss: 0.0083
# Epoch 338/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0019 - val_loss: 0.0082
# Epoch 339/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0019 - val_loss: 0.0082
# Epoch 340/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0020 - val_loss: 0.0082
# Epoch 341/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0020 - val_loss: 0.0081
# Epoch 342/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0021 - val_loss: 0.0080
# Epoch 343/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0021 - val_loss: 0.0080
# Epoch 344/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0022 - val_loss: 0.0079
# Epoch 345/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0022 - val_loss: 0.0079
# Epoch 346/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0023 - val_loss: 0.0078
# Epoch 347/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0023 - val_loss: 0.0078
# Epoch 348/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0024 - val_loss: 0.0077
# Epoch 349/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0024 - val_loss: 0.0077
# Epoch 350/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0024 - val_loss: 0.0076
# Epoch 351/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0025 - val_loss: 0.0076
# Epoch 352/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0025 - val_loss: 0.0076
# Epoch 353/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0026 - val_loss: 0.0075
# Epoch 354/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0026 - val_loss: 0.0075
# Epoch 355/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0026 - val_loss: 0.0074
# Epoch 356/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0027 - val_loss: 0.0074
# Epoch 357/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0027 - val_loss: 0.0073
# Epoch 358/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0027 - val_loss: 0.0073
# Epoch 359/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0028 - val_loss: 0.0073
# Epoch 360/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0028 - val_loss: 0.0073
# Epoch 361/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0028 - val_loss: 0.0072
# Epoch 362/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0029 - val_loss: 0.0072
# Epoch 363/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0029 - val_loss: 0.0072
# Epoch 364/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0029 - val_loss: 0.0071
# Epoch 365/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0030 - val_loss: 0.0071
# Epoch 366/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0030 - val_loss: 0.0070
# Epoch 367/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0030 - val_loss: 0.0070
# Epoch 368/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0031 - val_loss: 0.0070
# Epoch 369/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0031 - val_loss: 0.0070
# Epoch 370/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0031 - val_loss: 0.0069
# Epoch 371/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0031 - val_loss: 0.0069
# Epoch 372/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0032 - val_loss: 0.0069
# Epoch 373/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0032 - val_loss: 0.0068
# Epoch 374/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0032 - val_loss: 0.0068
# Epoch 375/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0032 - val_loss: 0.0068
# Epoch 376/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0033 - val_loss: 0.0067
# Epoch 377/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0033 - val_loss: 0.0067
# Epoch 378/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0033 - val_loss: 0.0067
# Epoch 379/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0033 - val_loss: 0.0067
# Epoch 380/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0034 - val_loss: 0.0067
# Epoch 381/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0034 - val_loss: 0.0066
# Epoch 382/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0034 - val_loss: 0.0066
# Epoch 383/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0034 - val_loss: 0.0066
# Epoch 384/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0034 - val_loss: 0.0066
# Epoch 385/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0035 - val_loss: 0.0066
# Epoch 386/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0035 - val_loss: 0.0065
# Epoch 387/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0035 - val_loss: 0.0065
# Epoch 388/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0035 - val_loss: 0.0065
# Epoch 389/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0035 - val_loss: 0.0065
# Epoch 390/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0036 - val_loss: 0.0064
# Epoch 391/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0036 - val_loss: 0.0064
# Epoch 392/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0036 - val_loss: 0.0064
# Epoch 393/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0036 - val_loss: 0.0064
# Epoch 394/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0036 - val_loss: 0.0064
# Epoch 395/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0036 - val_loss: 0.0064
# Epoch 396/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0036 - val_loss: 0.0063
# Epoch 397/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0037 - val_loss: 0.0063
# Epoch 398/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0037 - val_loss: 0.0063
# Epoch 399/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0037 - val_loss: 0.0063
# Epoch 400/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0037 - val_loss: 0.0063
# Epoch 401/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0037 - val_loss: 0.0063
# Epoch 402/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0037 - val_loss: 0.0062
# Epoch 403/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0037 - val_loss: 0.0062
# Epoch 404/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0037 - val_loss: 0.0062
# Epoch 405/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0038 - val_loss: 0.0062
# Epoch 406/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0038 - val_loss: 0.0062
# Epoch 407/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0038 - val_loss: 0.0062
# Epoch 408/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0038 - val_loss: 0.0061
# Epoch 409/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0038 - val_loss: 0.0062
# Epoch 410/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0038 - val_loss: 0.0061
# Epoch 411/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0038 - val_loss: 0.0061
# Epoch 412/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0038 - val_loss: 0.0061
# Epoch 413/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0038 - val_loss: 0.0061
# Epoch 414/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0038 - val_loss: 0.0061
# Epoch 415/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0061
# Epoch 416/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0039 - val_loss: 0.0061
# Epoch 417/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0061
# Epoch 418/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0061
# Epoch 419/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0061
# Epoch 420/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 421/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 422/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 423/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 424/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 425/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 426/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 427/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 428/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 429/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 430/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0039 - val_loss: 0.0060
# Epoch 431/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0060
# Epoch 432/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0060
# Epoch 433/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0060
# Epoch 434/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0060
# Epoch 435/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0060
# Epoch 436/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0060
# Epoch 437/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 438/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 439/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 440/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 441/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 442/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 443/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 444/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 445/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 446/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 447/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 448/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 449/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 450/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 451/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 452/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 453/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 454/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 455/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 456/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 457/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0058
# Epoch 458/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 459/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 460/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 461/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 462/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0058
# Epoch 463/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 464/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 465/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 466/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 467/500
# 38/38 [==============================] - 1s 25ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 468/500
# 38/38 [==============================] - 1s 23ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 469/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0058
# Epoch 470/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0059
# Epoch 471/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0058
# Epoch 472/500
# 38/38 [==============================] - 1s 24ms/step - loss: -0.0040 - val_loss: 0.0058

# %%
# loss trajectory를 확인한다.
plt.figure(figsize=(6, 4))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 조회용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()

check_w(0)
# Out:
# 1/1 [==============================] - 0s 406ms/step

# %%
N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 Markowitz 모델을 가져온다.
SAVE_MODEL = 'Markowitz_network_final.h5'
model = load_model(SAVE_MODEL, compile = True, custom_objects={'markowitz_objective': markowitz_objective})
model.summary()

# 백 테스트를 수행한다.
prt_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
mvstd_value = [10000]    # MV_std의 초기 value
mvshp_value = [10000] # MV_sharpe의 초기 value
mvVaR_value = [10000] # MV_VaR의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_history = []
w_history_std = []
w_history_shp = []
w_history_VaR = []
for i in range(0, xc_test.shape[0], N_FUTURE):
   
    # 이 시점에 각 종목을 w_prt 비율대로 매수한다.
    # 학습할 때 월간 수익률로 변환했으므로, 여기서도 변환해야 한다.
    x = xc_test[i][np.newaxis,:,:] * 5
    w_prt = model.predict(x)[0]
    w_history.append(w_prt)
    
    # 추가 코드
    x_mean = np.mean(x[0], axis=0)
    x_cov = np.cov(x[0].T)
    
    result_std = portfolio_optimization_std(w_crp, x_mean, x_cov)
    w_std = np.array([round(x,3) for x in result_std['x']])
    
    result_sharpe = portfolio_optimization_sharpe(w_crp, x_mean, x_cov, 0)
    w_shp = np.array([round(x,3) for x in result_sharpe['x']])
    
    result_VaR = portfolio_optimization_sharpe(w_crp, x_mean, x_cov, 0.05)
    w_VaR = np.array([round(x,3) for x in result_VaR['x']])
    
    w_history_std.append(w_std)
    w_history_shp.append(w_shp)
    w_history_VaR.append(w_VaR)

    # 다음 기간의 누적 수익률
    m_rtn = np.sum(xf_test[i], axis = 0) / 5
 
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    prt_value.append(prt_value[-1] * np.exp(np.dot(w_prt, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))
    
    mvstd_value.append(mvstd_value[-1] * np.exp(np.dot(w_std, m_rtn)))
    mvshp_value.append(mvshp_value[-1] * np.exp(np.dot(w_shp, m_rtn)))
    mvVaR_value.append(mvVaR_value[-1] * np.exp(np.dot(w_VaR, m_rtn)))

    # 추가로 발생한 시장 데이터로 MPN을 추가 학습시킨다.
    # xc_test[0] ~ xc_test[19],
    # xf_test[0] ~ xf_test[19]를 추가로 학습시킬 수 있다.
    xc_new = xc_test[i:(i+N_FUTURE), :, :]
    xf_new = xf_test[i:(i+N_FUTURE), :, :]

    # xc_train 데이터에서 80개를 random sampling 한다.
    idx = np.random.randint(0, xc_train.shape[0], 65)

    # 추가 학습 데이터를 생성한다.
    x = np.vstack([xc_new, xc_train[idx]])
    y = np.vstack([xf_new, xf_train[idx]])
    x, y = shuffle(x, y)

    # 추가 학습한다.
    x *= 5.0
    y *= 5.0
    model.fit(x, y, epochs=50, batch_size=10, verbose=0)

    # 추가로 발생한 데이터도 이후에 sampling될 수 있도록 보관해 둔다.
    xc_train = np.vstack([xc_train, xc_new])
    xf_train = np.vstack([xf_train, xf_new])

# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, xc_test.shape[0] + 5, N_FUTURE)

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value, 'markowitz':prt_value, 'MV_Std':mvstd_value, 'MV_Max_Shp':mvshp_value, 'MV_VaR':mvVaR_value})
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 60, 15)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                20480
# _________________________________________________________________
# dense (Dense)                (None, 15)                975
# _________________________________________________________________
# activation (Activation)      (None, 15)                0
# =================================================================
# Total params: 21,455
# Trainable params: 21,455
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save(SAVE_MODEL + 'AdLearning.h5')

# %%
perf_df
# Out:
#              crp     markowitz        MV_Std    MV_Max_Shp        MV_VaR
# 0   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# 1    9867.214083   9656.260610   9993.198882  10042.235201   9585.894897
# 2    9935.446736   9728.143197  10004.035933   9916.524263   9311.031195
# 3   10029.411672  10085.559286  10003.193383   9966.851761  10298.372776
# 4    9937.212241   9916.712954   9991.080563   9923.780957   8975.587552
# 5    9818.123994   9653.946792   9978.675318   9941.746804   9095.840819
# 6    9857.481636   9696.074446   9985.341649   9949.493012   9384.267798
# 7    9752.216152   9580.018374   9989.892066   9957.326094   9526.220774
# 8    9662.904822   9443.595803   9991.481752   9964.684523   9990.054112
# 9    9706.386334   9466.063808   9989.437866   9961.853259  10237.794222
# 10   9820.317158   9717.366878   9992.694190   9959.246390  10367.992682
# 11   9761.269650   9412.751592   9995.734502   9967.315506  10910.488159
# 12   9501.622503   9127.729042   9985.100007   9956.822951   9905.967290
# 13   9593.915256   9226.268292   9987.882575   9965.725645   9906.871681
# 14   9455.324034   9065.132108   9985.403120   9967.429788   8996.383448
# 15   9417.033640   8967.736010   9984.078787   9967.117586   9104.556409
# 16   9564.589723   9156.522676   9983.087526   9964.765787   8798.066379
# 17   9570.913599   9155.399479   9988.947049   9960.741951   8367.885219
# 18   9612.404913   9221.294369   9997.309947   9963.485492   7617.649077
# 19   9689.193919   9491.786951  10000.520361   9967.401415   7923.077375
# 20   9562.076682   9206.514251  10004.591108   9975.909151   7763.050539
# 21   9492.209705   9081.193239   9999.577885   9960.102717   7561.600739
# 22   9359.774089   8666.293006  10005.315850   9973.457676   7331.935168
# 23   9335.140912   8582.663347  10010.521925   9995.907261   7181.718404
# 24   8991.681965   7969.413166  10000.935779   9999.285428   6418.970483
# 25   9061.899608   8221.434715  10015.230132  10016.151731   7476.665428
# 26   9132.543457   8351.473528  10014.120176  10012.802594   6930.245533
# 27   9153.420349   8626.053619  10003.945355  10012.749182   7139.441540
# 28   9220.918930   8654.817387   9999.737799  10009.765629   7394.660938
# 29   9226.303846   8441.137406   9998.695885  10000.140689   7182.117705
# 30   9404.370140   8836.608432  10010.063219  10006.872331   7162.034421
# 31   9347.987976   8839.012305  10021.709980  10021.164045   6382.988654
# 32   9414.576069   8961.659990  10032.581284  10031.186713   6692.599117
# 33   9332.432946   8640.675164  10040.373740  10040.973229   5942.840069
# 34   9307.590044   8496.858728  10049.223248  10048.200779   5733.923622
# 35   9274.527988   8483.559292  10053.542717  10058.805498   5753.503863
# 36   9255.820166   8447.149277  10072.082593  10083.467812   5327.559488
# 37   9481.335380   8856.944279  10079.491879  10100.365657   5584.984140
# 38   9540.732363   8887.174804  10100.524574  10122.764082   5603.484535
# 39   9534.259932   9051.345725  10109.286199  10131.010374   5614.174976
# 40   9598.375129   9128.631579  10116.109538  10136.474691   5636.173027
# 41   9550.376907   8834.373164  10115.600728  10136.089446   5646.037710
# 42   9540.689912   8807.231657  10124.577828  10144.583997   5619.911596
# 43   9554.380429   8676.195785  10131.970302  10153.534631   5864.255633
# 44   9469.020545   8605.927623  10147.169516  10169.639546   5759.536766
# 45   9565.078726   8637.401409  10158.742676  10182.017329   6028.813643
# 46   9721.554612   8933.311872  10167.823608  10192.125457   6278.144615
# 47   9860.850529   8916.658438  10178.779620  10207.758454   6730.165205
# 48   9858.696648   9037.005469  10184.658697  10214.034117   6776.756882
# 49   9710.955467   8825.262598  10190.197411  10218.210442   6224.815115
# 50   9742.395782   8993.341787  10201.172592  10229.997194   6212.390343
# 51   9754.076690   9033.978282  10206.244060  10235.609157   6281.969115

# %%
perf_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ---

# %% [markdown]
# ## 2005년부터 2022년까지 학습, 2002년~2005년 테스트

# %%
df = pd.read_csv(colab_path + "top50-Stock_LogReturn.csv", index_col="Date")
train, test = df[1053:], df[:1053]

train_len = len(train)
test_len = len(test)
validation_set_len = 80
validation_set_split_point = 60

xc_train = np.empty((train_len - validation_set_len, 60, 50))
xf_train = np.empty((train_len - validation_set_len, 20, 50))
xc_test = np.empty((test_len - validation_set_len, 60, 50))
xf_test = np.empty((test_len - validation_set_len, 20, 50))

for idx in range(train_len - validation_set_len):
    temp_xc_train = train[idx : idx + validation_set_split_point]
    temp_xf_train = train[idx + validation_set_split_point : idx + validation_set_len]

    xc_train[idx] = temp_xc_train
    xf_train[idx] = temp_xf_train

for idx in range(test_len - validation_set_len):
    temp_xc_test = test[idx : idx + validation_set_split_point]
    temp_xf_test = test[idx + validation_set_split_point : idx + validation_set_len]

    xc_test[idx] = temp_xc_test
    xf_test[idx] = temp_xf_test
    
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') * 20
xf_train = xf_train.astype('float32') * 20
xc_test = xc_test.astype('float32') * 20
xf_test = xf_test.astype('float32') * 20

N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
xc_train, xf_train = shuffle(xc_train, xf_train)
test_len, train_len - validation_set_len
# Out:
# (1053, 4132)

# %%
# LSTM으로 Markowitz 모델을 생성한다.
xc_input = tf.keras.Input(batch_shape = (None, N_TIME, N_STOCKS))
h_lstm = LSTM(64, dropout = 0.2, kernel_regularizer=l2(0.01))(xc_input)
y_output = Dense(N_STOCKS, activation='tanh')(h_lstm)  # linear projection

# 특정 종목을 과도하게 매수하는 것을 방지하기 위해 위에서 tanh를 사용했다. 
# (over confidence 방지용). REG_CONST를 적용했기 때문에 이미 고려된 사항이지만, 
# 안전을 위해 추가했다. ex : [-3, 0.4, 0.2, +20] --> [-0.995, 0.380, 0.197, 1.0]|

# 마코비츠의 최적 weights
y_output = Activation('softmax')(y_output)
model = tf.keras.Model(xc_input, y_output)

# %%
from keras import callbacks
# # MPN을 학습하고 결과를 저장한다.
SAVE_MODEL = 'Markowitz_network_CV_final'
ealry_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.compile(loss = markowitz_objective, optimizer = Adam(learning_rate = 1e-6))
hist = model.fit(xc_train, xf_train, epochs=500, batch_size = 32, validation_data = (xc_test, xf_test), callbacks=[ealry_stopping])
model.save(SAVE_MODEL + '.h5')

# %%
# loss trajectory를 확인한다.
plt.figure(figsize=(6, 4))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 조회용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()

check_w(0)

# %%
N_TIME = xc_test.shape[1]
N_FUTURE = xf_test.shape[1]
N_STOCKS = xf_test.shape[2]

# 저장된 Markowitz 모델을 가져온다.
SAVE_MODEL = 'Markowitz_network_final.h5AdLearning.h5'
model = load_model(SAVE_MODEL, compile = True, custom_objects={'markowitz_objective': markowitz_objective})
model.summary()

# 백 테스트를 수행한다.
prt_value = [10000]   # portfolio의 초기 value
crp_value = [10000]   # CRP의 초기 value
mvstd_value = [10000]    # MV_std의 초기 value
mvshp_value = [10000] # MV_sharpe의 초기 value
mvVaR_value = [10000] # MV_VaR의 초기 value
w_crp = np.ones(N_STOCKS) / N_STOCKS   # CRP 비율 (균등 비율)

w_history = []
w_history_std = []
w_history_shp = []
w_history_VaR = []
for i in range(0, xc_test.shape[0], N_FUTURE):
   
    # 이 시점에 각 종목을 w_prt 비율대로 매수한다.
    # 학습할 때 월간 수익률로 변환했으므로, 여기서도 변환해야 한다.
    x = xc_test[i][np.newaxis,:,:] * 20
    w_prt = model.predict(x)[0]
    w_history.append(w_prt)
    
    # 추가 코드
    x_mean = np.mean(x[0], axis=0)
    x_cov = np.cov(x[0].T)
    
    result_std = portfolio_optimization_std(w_crp, x_mean, x_cov)
    w_std = np.array([round(x,3) for x in result_std['x']])
    
    result_sharpe = portfolio_optimization_sharpe(w_crp, x_mean, x_cov, 0)
    w_shp = np.array([round(x,3) for x in result_sharpe['x']])
    
    result_VaR = portfolio_optimization_sharpe(w_crp, x_mean, x_cov, 0.05)
    w_VaR = np.array([round(x,3) for x in result_VaR['x']])
    
    w_history_std.append(w_std)
    w_history_shp.append(w_shp)
    w_history_VaR.append(w_VaR)

    # 다음 기간의 누적 수익률
    m_rtn = np.sum(xf_test[i], axis = 0) / 20
 
    # 누적 수익률과 w_prt (W)로 포트폴리오의 수익률을 계산한다.
    prt_value.append(prt_value[-1] * np.exp(np.dot(w_prt, m_rtn)))
    crp_value.append(crp_value[-1] * np.exp(np.dot(w_crp, m_rtn)))
    
    mvstd_value.append(mvstd_value[-1] * np.exp(np.dot(w_std, m_rtn)))
    mvshp_value.append(mvshp_value[-1] * np.exp(np.dot(w_shp, m_rtn)))
    mvVaR_value.append(mvVaR_value[-1] * np.exp(np.dot(w_VaR, m_rtn)))

    # 추가로 발생한 시장 데이터로 MPN을 추가 학습시킨다.
    # xc_test[0] ~ xc_test[19],
    # xf_test[0] ~ xf_test[19]를 추가로 학습시킬 수 있다.
    xc_new = xc_test[i:(i+N_FUTURE), :, :]
    xf_new = xf_test[i:(i+N_FUTURE), :, :]

    # xc_train 데이터에서 80개를 random sampling 한다.
    idx = np.random.randint(0, xc_train.shape[0], 80)

    # 추가 학습 데이터를 생성한다.
    x = np.vstack([xc_new, xc_train[idx]])
    y = np.vstack([xf_new, xf_train[idx]])
    x, y = shuffle(x, y)

    # 추가 학습한다.
    x *= 20.0
    y *= 20.0
    model.fit(x, y, epochs=50, batch_size=10, verbose=0)

    # 추가로 발생한 데이터도 이후에 sampling될 수 있도록 보관해 둔다.
    xc_train = np.vstack([xc_train, xc_new])
    xf_train = np.vstack([xf_train, xf_new])

# 평가 시점의 날짜를 발췌한다.
idx = np.arange(0, xc_test.shape[0] + 20, N_FUTURE)

# 벤치마크를 위한 S&P500 정의
us500 = fdr.DataReader('US500', '2002-01-01', '2022-12-01')\
    ['Adj Close'][1:993][idx]
us500_value = us500 / us500[0] * 10000

# Markowitz 성과와 CRP 성과를 데이터 프레임에 기록해 둔다.
perf_df = pd.DataFrame({'crp':crp_value, 'markowitz':prt_value, 'MV_Std':mvstd_value, 'MV_Max_Shp':mvshp_value, 'MV_VaR':mvVaR_value,'S&P500':us500_value})

# %%
model.save(SAVE_MODEL + 'AdLearning.h5')

# %% [markdown]
# ## 예언자 Prophet 학습

# %%
df = pd.read_csv(colab_path + "top50-Stock_LogReturn.csv", index_col="Date")
train, test = df, train_test_split(df, test_size=0.2, shuffle=False)[1]

train_len = len(train)
test_len = len(test)
validation_set_len = 80
validation_set_split_point = 60

xc_train = np.empty((train_len - validation_set_len, 60, 50))
xf_train = np.empty((train_len - validation_set_len, 20, 50))
xc_test = np.empty((test_len - validation_set_len, 60, 50))
xf_test = np.empty((test_len - validation_set_len, 20, 50))

for idx in range(train_len - validation_set_len):
    temp_xc_train = train[idx : idx + validation_set_split_point]
    temp_xf_train = train[idx + validation_set_split_point : idx + validation_set_len]

    xc_train[idx] = temp_xc_train
    xf_train[idx] = temp_xf_train

for idx in range(test_len - validation_set_len):
    temp_xc_test = test[idx : idx + validation_set_split_point]
    temp_xf_test = test[idx + validation_set_split_point : idx + validation_set_len]

    xc_test[idx] = temp_xc_test
    xf_test[idx] = temp_xf_test
    
# 월간 수익률 정도의 스케일로 변환한다
xc_train = xc_train.astype('float32') * 20
xf_train = xf_train.astype('float32') * 20
xc_test = xc_test.astype('float32') * 20
xf_test = xf_test.astype('float32') * 20

N_TIME = xc_train.shape[1]
N_FUTURE = xf_train.shape[1]
N_STOCKS = xf_train.shape[2]

# 학습 데이터는 shuffling 한다.
xc_train, xf_train = shuffle(xc_train, xf_train)
test_len, train_len - validation_set_len
# Out:
# (1053, 5185)

# %%
# LSTM으로 Markowitz 모델을 생성한다.
xc_input = tf.keras.Input(batch_shape = (None, N_TIME, N_STOCKS))
h_lstm = LSTM(64, dropout = 0.2, kernel_regularizer=l2(0.01))(xc_input)
y_output = Dense(N_STOCKS, activation='tanh')(h_lstm)  # linear projection

# 특정 종목을 과도하게 매수하는 것을 방지하기 위해 위에서 tanh를 사용했다. 
# (over confidence 방지용). REG_CONST를 적용했기 때문에 이미 고려된 사항이지만, 
# 안전을 위해 추가했다. ex : [-3, 0.4, 0.2, +20] --> [-0.995, 0.380, 0.197, 1.0]|

# 마코비츠의 최적 weights
y_output = Activation('softmax')(y_output)
model = tf.keras.Model(xc_input, y_output)

# # MPN을 학습하고 결과를 저장한다.
SAVE_MODEL = 'prophet'
ealry_stopping = EarlyStopping(monitor='val_loss', patience=10)

model.compile(loss = markowitz_objective, optimizer = Adam(learning_rate = 1e-6))
hist = model.fit(xc_train, xf_train, epochs=500, batch_size = 32, validation_data = (xc_test, xf_test), callbacks=[ealry_stopping])
model.save(SAVE_MODEL + '.h5')

# loss trajectory를 확인한다.
plt.figure(figsize=(6, 4))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.legend()
plt.show()

# 최적 포트폴리오 결과 조회용 코드
def check_w(n = 0):
    plt.figure(figsize=(8, 4))
    y_pred = model.predict(xc_test[n].reshape(1, N_TIME, N_STOCKS))[0]
    plt.bar(np.arange(N_STOCKS), y_pred, alpha = 0.7)
    plt.show()

check_w(0)

# %% [markdown]
# ---
